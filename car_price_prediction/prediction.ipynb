# %% [markdown]
# <a href="https://colab.research.google.com/github/virajbhutada/OIBSIP/blob/main/Task_3_Car_Price_Prediction_with_Machine_Learning(OIBSIP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car Price Prediction with Machine Learning
#
# The price of a car depends on a lot of factors like the goodwill of the brand of the car,
# features of the car, horsepower and the mileage it gives and many more. Car price
# prediction is one of the major research areas in machine learning.
#
# ### Description
#
# In this task, the objective was to gain a comprehensive understanding of the dataset through Data Visualization and Exploration. Utilizing a variety of charts, graphs, and statistical techniques, the dataset was visually dissected to uncover patterns, trends, and inherent relationships within the data. Exploratory Data Analysis (EDA) techniques were applied, allowing for a detailed examination of the dataset's main characteristics. Through these visualizations, key insights were derived, offering a deeper perspective on the data. The visual exploration not only facilitated a nuanced understanding of the dataset but also served as a foundation for subsequent analyses, providing essential context for the overall project.
#
# Dataset - https://www.kaggle.com/datasets/ngawangchoeda/car-price-dataset

# %% [markdown]
# # Importing Necessary Libraries

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading and Exploring the Dataset

# %%
# Reading the csv file
df = pd.read_csv("CarPrice.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Handle missing values if any
data = df.dropna()

# %%
# Getting info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
# Checking if there is any null value or not
df.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Getting the shape of the dataset
df.shape
# Out:
# (205, 25)

# %%
# Descriptive statistical analysis of data
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
# Getting all the unique car names
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
# Checking the aspiration types
df.aspiration.value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
# Checking the fuel types
df.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
# Checking the door numbers
df.doornumber.value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
# Checking the carbody types
df.carbody.value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
# Checking the drive wheel types
df.drivewheel.value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
# Checking the engine location
df.enginelocation.value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
# Checking the fuel systems
df.fuelsystem.value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)/Data Visualization and Exploration

# %%
# distplot of the price column
sns.set_style("whitegrid")
plt.figure(figsize=(7, 5))
sns.distplot(df.price)
plt.show()

# %%
# Sample data (replace this with your actual data)
categories = ['(horsepower, price)', '(enginesize, price)', '(citympg, price)']
values = [30, 45, 25]  # Represents the distribution of each category

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Feature Pairs')
plt.show()

# %%
x = df.drop(['price', 'CarName', 'fueltype', 'aspiration',	'doornumber', 'carbody',	'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'], axis=1)
x
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
y = df['price']
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# # Splitting the data into training and testing sets

# %%
# Importing train test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1234)

# %% [markdown]
# Creating Model and making Prediction
# # Linear Regression

# %%
# Linear Regression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
linear_predictions = linear_model.predict(X_test)

# Evaluation
linear_mse = mean_squared_error(y_test, linear_predictions)
linear_r2 = r2_score(y_test, linear_predictions)

linear_mse, linear_r2
# Out:
# (15730865.74305523, 0.8007339179361617)

# %%
# Importing Linear Regression library
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_train)
y_pred
# Out:
# array([ 6118.54422044, 16329.35470549,  6295.53867835, 11985.3940228 ,
#        40555.5972669 ,  5676.90730689, 31947.31622738, 23303.61003393,
#         6412.90807551,  9980.42428456,  6771.29445703,  8103.63503348,
#        17256.14869094, 18293.36983909, 30588.22137712, 12873.08309998,
#        17773.4493793 , 17401.22461339,  7679.06460729, 11924.94836195,
#         7576.56453237,  9293.58431697, 16867.72437477,  8534.60486258,
#        10377.78902865, 34524.31578205, 48012.74730434, 15410.1577326 ,
#        10116.42451503, 10398.1312177 , 10246.48273659,  5677.3179905 ,
#         6362.13533283,  6445.91035825, 11262.54780785, 11131.75429906,
#         8265.81607107,  6718.01715239, 10217.81026985, 11715.52693916,
#         9522.36804702, 10358.74712904,  8303.59238699, 11073.1150882 ,
#        24470.78665088,  8380.4850743 , 14797.02388201,  7133.40023429,
#        14574.33736139,  6617.32498929, 27576.18152647,  6715.44444008,
# ...

# %% [markdown]
# # Actual vs Predicted "Price" Graph

# %%
plt.scatter(y_train,y_pred)
plt.xlabel('Actual price')
plt.ylabel('Predicted price')
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # Lasso Regression

# %%
# Lasso Regression
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)
lasso_predictions = lasso_model.predict(X_test)

# Evaluation
lasso_mse = mean_squared_error(y_test, lasso_predictions)
lasso_r2 = r2_score(y_test, lasso_predictions)

lasso_mse, lasso_r2
# Out:
# (15729720.41678039, 0.8007484260174841)

# %%
from sklearn.linear_model import Lasso

model1 = Lasso()
model1.fit(x_train, y_train)
# Out:
# Lasso()

# %% [markdown]
# # Predicition

# %%
y_pred1 = model1.predict(x_train)
y_pred1
# Out:
# array([ 6121.42309304, 16336.92873174,  6286.65275879, 11990.24052303,
#        40549.52956463,  5672.35715681, 31959.91753698, 23299.26755228,
#         6414.93582517,  9988.8075274 ,  6765.10580466,  8103.82915569,
#        17260.80627858, 18304.23349911, 30582.8011063 , 12873.65916939,
#        17780.14977352, 17394.01591886,  7673.48513825, 11921.34207755,
#         7566.54131109,  9303.98706985, 16885.86524646,  8533.00161499,
#        10385.57050233, 34517.77177467, 47990.29770335, 15428.95418739,
#        10119.64090014, 10385.9486296 , 10250.68587247,  5679.6669091 ,
#         6364.14282904,  6447.95127265, 11261.60466713, 11134.77081452,
#         8267.74540145,  6714.15463938, 10220.18907981, 11721.24619334,
#         9523.05768983, 10372.52324122,  8302.79040346, 11078.59272318,
#        24473.1160324 ,  8379.29426139, 14790.68613074,  7124.95280683,
#        14587.18826688,  6604.85551712, 27580.64241441,  6709.23350891,
# ...

# %%
plt.scatter(y_train, y_pred1)
plt.xlabel('Actual price')
plt.ylabel('Predicted price')
plt.title("Actual vs Predicted")
plt.show()

# %%
# Visualization: Actual vs. Predicted (Scatter Plot with Regression Line)
plt.figure(figsize=(10, 6))

# Scatter plot for actual prices
plt.scatter(y_test.values, linear_predictions, color='blue', label='Linear Regression', alpha=0.7)
plt.scatter(y_test.values, lasso_predictions, color='red', label='Lasso Regression', alpha=0.7)

# Plotting the regression line for linear regression
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='green', linewidth=2, linestyle='--', label='Perfect Prediction')

plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Car Prices')
plt.legend()
plt.show()

# %%
# Visualization: Actual vs. Predicted (Line Plot)
plt.figure(figsize=(10, 6))

# Plotting actual prices
plt.plot(y_test.values, color='green', label='Actual Prices', linewidth=2)

# Plotting linear regression predictions
plt.plot(linear_predictions, color='blue', label='Linear Regression Predictions', linewidth=2)

# Plotting lasso regression predictions
plt.plot(lasso_predictions, color='red', label='Lasso Regression Predictions', linewidth=2)

plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Car Prices (Line Plot)')
plt.legend()
plt.show()

# %% [markdown]
# ### Conclusion
#
# In this project, we delved into the Car Price dataset, employing machine learning techniques like Linear Regression and Lasso Regression. Through intensive analysis and data-driven visualizations, intricate patterns emerged, shedding light on the factors influencing car prices. Leveraging advanced machine learning methodologies, our exploration provided deep insights, unveiling the complexities of pricing dynamics. By combining statistical models with compelling visuals, we gained a comprehensive understanding, enabling data-powered decisions in the realm of car pricing and beyond.
